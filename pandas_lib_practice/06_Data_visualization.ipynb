# %% [markdown]
# # Data Visualization (#dataviz)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import titanic data from seaborn lib
df = sns.load_dataset('titanic')

# %%
# create plot
df.plot(kind='scatter', x = 'age', y='fare', color='green')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
df.groupby('sex')['age'].mean().plot(kind='bar')
plt.ylabel("Average Fare")
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
sns.scatterplot(data=df, x='age', y='fare', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# make scatter plot via plotly
import plotly.express as px

fig = px.scatter( df, x='age', y='fare', color='class')
fig.show()
# Out:
# c:\Users\jahirul_islam\miniconda3\envs\python_eda\Lib\site-packages\plotly\express\_core.py:2044: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(required_grouper, sort=False)  # skip one_group groupers

# %%
import plotly.graph_objects as go
import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
# world figure with plotly
import plotly.express as px
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[25,90])

# %% [markdown]
# ### Read the docs of every libs
# ### create 10 different plots on different datasets each tie useing each of these four libs.
# ### Interpret them and provide the insights you take from each plot in 3-4 lines.
# ### Finalize one notebook and send it to the teacher.
#
# ## use these Four libraries.
# 1. pandas
# 2. matplotly
# 3. searborn
# 4. ploty
